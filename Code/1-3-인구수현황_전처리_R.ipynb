# %% [markdown]
# ## 읍면동별 인구수

# %%
library(dplyr)
library(reshape2)
library(rgdal)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: sp
#
# rgdal: version: 1.5-16, (SVN revision 1050)
# Geospatial Data Abstraction Library extensions to R successfully loaded
# Loaded GDAL runtime: GDAL 3.1.2, released 2020/07/07
# Path to GDAL shared files: /usr/local/gdal-3.1.2/share/gdal
# GDAL binary built with GEOS: FALSE
# Loaded PROJ runtime: Rel. 6.1.0, May 15th, 2019, [PJ_VERSION: 610]
# Path to PROJ shared files: /usr/local/proj-6.1.0/share/proj
# Linking to sp version:1.4-2
# To mute warnings of possible GDAL/OSR exportToProj4() degradation,
# use options("rgdal_show_exportToProj4_warnings"="none") before loading rgdal.

# %%
people <- read.csv("07.광양시_법정동별_인구현황(읍면동리).csv",header=T)
people
# Out:
#    읍면동 법정리 세대수 계    남자  여자
# 1  광양읍 우산리  597    1318  658   660
# 2  광양읍 구산리 2628    7125 3530  3595
# 3  광양읍 칠성리 3921    7940 4051  3889
# 4  광양읍 읍내리  351     640  352   288
# 5  광양읍 목성리 1506    2827 1456  1371
# 6  광양읍 인동리  265     458  243   215
# 7  광양읍 인서리 1549    3211 1675  1536
# 8  광양읍 익신리  173     279  141   138
# 9  광양읍 초남리  161     248  123   125
# 10 광양읍 사곡리  213     357  187   170
# 11 광양읍 죽림리  220     372  190   182
# 12 광양읍 용강리 4005   12628 6386  6242
# 13 광양읍 도월리  228     405  188   217
# 14 광양읍 세풍리  415     775  390   385
# 15 광양읍 덕례리 5162   10693 5638  5055
# 16 봉강면 석사리  252     476  251   225
# 17 봉강면 지곡리  120     250  126   124
# 18 봉강면 봉당리  191     370  193   177
# 19 봉강면 부저리  172     354  183   171
# 20 봉강면 구서리  119     220  105   115
# 21 봉강면 조령리  155     297  156   141
# 22 봉강면 신룡리  110     217  120    97
# 23 옥룡면 산남리  149     291  142   149
# 24 옥룡면 운평리  225     399  194   205
# 25 옥룡면 추산리  220     417  211   206
# 26 옥룡면 동곡리  238     444  228   216
# ...

# %%
(people_use <- people %>%
    group_by(읍면동) %>%
    summarise(인구수=sum(계)))
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#    읍면동 인구수
# 1  골약동  1690
# 2  광양읍 49276
# 3  광영동 12534
# 4  금호동 12497
# 5  다압면  1816
# 6  봉강면  2184
# 7  옥곡면  2850
# 8  옥룡면  3118
# 9  중마동 58479
# 10 진상면  2884
# 11 진월면  2849
# 12 태인동  1839

# %%
write.csv(people_use,"읍별인구수.csv",row.names=F)
