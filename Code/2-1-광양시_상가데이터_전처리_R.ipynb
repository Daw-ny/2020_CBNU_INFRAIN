# %%
library(dplyr)
library(reshape2)
library(rgdal)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: sp
#
# rgdal: version: 1.5-16, (SVN revision 1050)
# Geospatial Data Abstraction Library extensions to R successfully loaded
# Loaded GDAL runtime: GDAL 3.1.2, released 2020/07/07
# Path to GDAL shared files: /usr/local/gdal-3.1.2/share/gdal
# GDAL binary built with GEOS: FALSE
# Loaded PROJ runtime: Rel. 6.1.0, May 15th, 2019, [PJ_VERSION: 610]
# Path to PROJ shared files: /usr/local/proj-6.1.0/share/proj
# Linking to sp version:1.4-2
# To mute warnings of possible GDAL/OSR exportToProj4() degradation,
# use options("rgdal_show_exportToProj4_warnings"="none") before loading rgdal.

# %%
build <- read.csv("광양시_상가_데이터.csv",header=T)

# %%
build2 <- build %>% filter(상권업종대분류명 != "부동산")

# %%
build_use <- build2[,c(2,5,7,17,38,39)]

# %%
example <- build_use %>% 
    filter(상권업종중분류명=="주유소/충전소")
example
# Out:
#    상호명                     상권업종대분류명 상권업종중분류명 행정동명
# 1  대성에너지동광양충전소     생활서비스       주유소/충전소    광영동
# 2  태인주유소                 생활서비스       주유소/충전소    태인동
# 3  거성LPG주유소              생활서비스       주유소/충전소    광양읍
# 4  현대오일뱅크서울지점       생활서비스       주유소/충전소    태인동
# 5  제이와이지                 생활서비스       주유소/충전소    광양읍
# 6  희망찬충전소               생활서비스       주유소/충전소    골약동
# 7  남강주유소.티켓나라광양점  생활서비스       주유소/충전소    광양읍
# 8  희망찬주유소               생활서비스       주유소/충전소    골약동
# 9  정품주유소                 생활서비스       주유소/충전소    광양읍
# 10 신중마주유소               생활서비스       주유소/충전소    중마동
# 11 현대정유제철주유소         생활서비스       주유소/충전소    광영동
# 12 지케이광양제철주유소       생활서비스       주유소/충전소    광영동
# 13 지에스넥스테이션협력주유소 생활서비스       주유소/충전소    태인동
# 14 현대오일뱅크직영도령주     생활서비스       주유소/충전소    태인동
# 15 에이제이토탈직영제철주유   생활서비스       주유소/충전소    광영동
# 16 한국가스광양LCNG복합충     생활서비스       주유소/충전소    광양읍
# 17 가온코리아직영협력주       생활서비스       주유소/충전소    태인동
# 18 하포주유소                 생활서비스       주유소/충전소    골약동
# ...

# %%
write.csv(build_use,"광양시_상가데이터.csv",row.names=F)

# %%
example$상권업종대분류명 %>% unique()
# Out:
# [1] 소매           음식           생활서비스     관광/여가/오락 학문/교육
# [6] 숙박           스포츠
# Levels: 관광/여가/오락 부동산 생활서비스 소매 숙박 스포츠 음식 학문/교육
